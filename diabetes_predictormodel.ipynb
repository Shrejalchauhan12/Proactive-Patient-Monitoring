# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score

# %% [markdown]
# # dataset reading

# %%
diabetes_dataset=pd.read_csv('C:\\Users\\Shivangi\\OneDrive\\Desktop\\Shivangi Singh\\HealthMate Smart Disease Predictor and Medical Assistant\\EDA file\\Cleaned_Diabetes.csv')

# %%
diabetes_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# # printing 5 rows of the dataset

# %%
diabetes_dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# # printing last 5 rows

# %%
diabetes_dataset.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %% [markdown]
# # no of rows and columns

# %%
diabetes_dataset.shape
# Out:
# (768, 9)

# %% [markdown]
# # separating the data and labels

# %%
X=diabetes_dataset.drop(columns='Outcome',axis=1)
Y=diabetes_dataset['Outcome']

# %%
print(X)
print(Y)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %% [markdown]
# # standarlize the data

# %%
scaler=StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
standardized_data=scaler.transform(X)

# %%
print(standardized_data)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]

# %%
X=standardized_data
Y=diabetes_dataset['Outcome']

# %% [markdown]
# # train and test the data

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8)

# %% [markdown]
# # Training the model

# %%
knn=KNeighborsClassifier()
knn.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier()

# %%
model=LogisticRegression()
model.fit(X_train,Y_train)
# Out:
# C:\Users\Shivangi\.ipython\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
clf = DecisionTreeClassifier()

# Fit the model
clf.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
model = RandomForestClassifier(
    n_estimators=100,     # number of trees
    max_depth=10,         # control tree depth
    min_samples_split=5,  # minimum samples to split
    random_state=42
)
model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(max_depth=10, min_samples_split=5, random_state=42)

# %% [markdown]
# # Training the svm classifier

# %%
classifier.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %%
# model evaluation (checking accuracy)
X_train_prediction=model.predict(X_train)
training_data_accuracy=accuracy_score(X_train_prediction,Y_train)

# %%
print('Accuracy Score of the training data: ',training_data_accuracy)
# Out:
# Accuracy Score of the training data:  0.9804560260586319

# %%
# model evaluation (checking accuracy on test data)
Y_test_prediction=model.predict(X_test)
test_data_accuracy=accuracy_score(Y_test_prediction,Y_test)
print('Accuracy Score of the test data: ',test_data_accuracy)
# Out:
# Accuracy Score of the test data:  0.7662337662337663

# %%
input_data=(0,89,97,23,94,28.1,0.167,22)
array=np.array(input_data)
s=array.reshape(1,-1)

std_data=scaler.transform(s)
print(std_data)
prediction=classifier.predict(std_data)
print(prediction)

if(prediction[0]==0):
    print("not diabetic")
else:
    print("diabetic")
# Out:
# [[-1.14185152 -0.99820778  1.4420845   0.15453319  0.12330164 -0.49404308
#   -0.92076261 -0.95646168]]
# [0]
# not diabetic
# C:\Users\Shivangi\.ipython\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
